# %% [markdown]
# # Q2
#
# En esta parte, la tarea consiste en llamar a MongoDB para realizar geoqueries y representar los datos geoespaciales con folium, mostrando en un mapa la geolocalizacion de la nueva oficina.

# %%
# Tu codigo aqui
from pymongo import MongoClient,GEOSPHERE
import folium
from bson.son import SON
import pandas as pd

# %%
client=MongoClient()
db=client.companiesDB

# %%
m = folium.Map(
    location=[39.157898,-101.646620],
    zoom_start=4
)

# %%
for loc in list(db.companies2.find({'type':'Big company'})):
    folium.CircleMarker([loc['loc_office']['coordinates'][1],loc['loc_office']['coordinates'][0]],color='red',radius=5,tooltip=(str(loc['loc_office']['coordinates'])+loc['name'])).add_to(m)

for loc in list(db.companies2.find({'type':'Start-up'})):
    folium.CircleMarker([loc['loc_office']['coordinates'][1],loc['loc_office']['coordinates'][0]],color='blue',radius=5,tooltip=(str(loc['loc_office']['coordinates'])+loc['name'])).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Para cada una de las empresas que encontramos podemos la cantidad de empresas a su alrededor y su
# ratio "Big/Startups"

# %%
db.companies2.create_index([("loc_office",GEOSPHERE)])
# Out:
# 'loc_office_2dsphere'

# %%
def search_2000m(x):
    near = db.companies2.find({"loc_office": {"$near": {"$geometry":x, "$maxDistance": 2000}}})
    near = near[1:]
    # A partir de las empresas encontradas al rededor de la empresa seleccionada, calculamos su ratio "Big/Startup"
    types_near = [1 if empr['type'] == 'Start-up' else 2 for empr in near]
    starts = types_near.count(1)
    bigs = types_near.count(2)
    if starts != 0:
        ratio = bigs/starts
    else:
        ratio = -1
    return (ratio,bigs,starts)

# %%
# Almacenamos la información en un DataFrame
companies = db.companies2.find()
companies = pd.DataFrame.from_dict(companies)
companies['ratio_Big_Start'] = companies['loc_office'].apply(search_2000m)

# %%
# Según el ratio calculado un valor de -1 es un punto en el cual tendríamos solo compañias grandes al rededor
# un ratio con valor mayor a 1 significa una mayor cantidad de empresas grandes que de startups,
# un ratio con valor menor a 1 y mayor a 0 significa que se tiene una mayor cantidad de startups al rededor.
# Todo en un radio de 2km
companies.sort_values('ratio_Big_Start',ascending=False)
# Out:
#                           _id    category_code  founded_year  \
# 21   5d58bb1119ab40d9eb30ed03              web          2005
# 1    5d58bb1119ab40d9eb30ecef              web          1995
# 31   5d58bb1119ab40d9eb30ed0d  network_hosting          2004
# 125  5d58bb1119ab40d9eb30ed6b              web          2004
# 184  5d58bb1119ab40d9eb30eda6              web          2007
# 99   5d58bb1119ab40d9eb30ed51  network_hosting          2005
# 92   5d58bb1119ab40d9eb30ed4a           mobile          2006
# 319  5d58bb1119ab40d9eb30ee2d           mobile          1999
# 323  5d58bb1119ab40d9eb30ee31              web          2003
# 362  5d58bb1119ab40d9eb30ee58              web          2008
# 73   5d58bb1119ab40d9eb30ed37           mobile          2003
# 350  5d58bb1119ab40d9eb30ee4c        ecommerce          2008
# 258  5d58bb1119ab40d9eb30edf0        ecommerce          2006
# 234  5d58bb1119ab40d9eb30edd8        ecommerce          2006
# 2    5d58bb1119ab40d9eb30ecf0              web          2002
# 77   5d58bb1119ab40d9eb30ed3b              web          2006
# 382  5d58bb1119ab40d9eb30ee6c  network_hosting          1993
# 252  5d58bb1119ab40d9eb30edea           mobile          2010
# 247  5d58bb1119ab40d9eb30ede5           mobile          2004
# 271  5d58bb1119ab40d9eb30edfd           mobile          2004
# 228  5d58bb1119ab40d9eb30edd2           mobile          2010
# 26   5d58bb1119ab40d9eb30ed08              web          2006
# 118  5d58bb1119ab40d9eb30ed64              web          2003
# 7    5d58bb1119ab40d9eb30ecf5              web          2002
# 149  5d58bb1119ab40d9eb30ed83        ecommerce          2007
# 395  5d58bb1119ab40d9eb30ee79              web          2009
# 17   5d58bb1119ab40d9eb30ecff              web          2006
# 182  5d58bb1119ab40d9eb30eda4  network_hosting          2007
# 164  5d58bb1119ab40d9eb30ed92              web          2007
# 111  5d58bb1119ab40d9eb30ed5d              web          2006
# ..                        ...              ...           ...
# 333  5d58bb1119ab40d9eb30ee3b           mobile          2008
# 76   5d58bb1119ab40d9eb30ed3a              web          2006
# 172  5d58bb1119ab40d9eb30ed9a              web          2006
# 330  5d58bb1119ab40d9eb30ee38        ecommerce          2008
# 79   5d58bb1119ab40d9eb30ed3d              web          2007
# 171  5d58bb1119ab40d9eb30ed99  network_hosting          2007
# 327  5d58bb1119ab40d9eb30ee35              web          2006
# 326  5d58bb1119ab40d9eb30ee34  network_hosting          2002
# 325  5d58bb1119ab40d9eb30ee33        ecommerce          2008
# 324  5d58bb1119ab40d9eb30ee32      photo_video          2007
# 86   5d58bb1119ab40d9eb30ed44        ecommerce          2007
# 87   5d58bb1119ab40d9eb30ed45              web          2007
# 88   5d58bb1119ab40d9eb30ed46              web          2007
# 89   5d58bb1119ab40d9eb30ed47              web          2006
# 302  5d58bb1119ab40d9eb30ee1c              web          2007
# 168  5d58bb1119ab40d9eb30ed96              web          2005
# 317  5d58bb1119ab40d9eb30ee2b              web          2007
# 316  5d58bb1119ab40d9eb30ee2a              web          2003
# 315  5d58bb1119ab40d9eb30ee29              web          2007
# 314  5d58bb1119ab40d9eb30ee28              web          2008
# 313  5d58bb1119ab40d9eb30ee27           mobile          2007
# 214  5d58bb1119ab40d9eb30edc4        ecommerce          2000
# 311  5d58bb1119ab40d9eb30ee25           mobile          2008
# 310  5d58bb1119ab40d9eb30ee24           mobile          2004
# 309  5d58bb1119ab40d9eb30ee23              web          2000
# 306  5d58bb1119ab40d9eb30ee20              web          2008
# 162  5d58bb1119ab40d9eb30ed90  network_hosting          2007
# 161  5d58bb1119ab40d9eb30ed8f  network_hosting          2003
# 303  5d58bb1119ab40d9eb30ee1d           mobile          2008
# 0    5d58bb1119ab40d9eb30ecee              web          2006
#
#                                             loc_office                name  \
# 21   {'type': 'Point', 'coordinates': [-122.301534,...              Zvents
# 1    {'type': 'Point', 'coordinates': [-121.930035,...                eBay
# 31   {'type': 'Point', 'coordinates': [-121.935688,...            Hightail
# 125  {'type': 'Point', 'coordinates': [-122.307887,...           SugarSync
# 184  {'type': 'Point', 'coordinates': [-122.227765,...           GreenNote
# 99   {'type': 'Point', 'coordinates': [-122.300246,...              fabrik
# 92   {'type': 'Point', 'coordinates': [-122.230116,...                 Qik
# 319  {'type': 'Point', 'coordinates': [-122.301534,...  Sonim Technologies
# 323  {'type': 'Point', 'coordinates': [-121.9303616...     Naseeb Networks
# 362  {'type': 'Point', 'coordinates': [-121.928393,...             Smallaa
# 73   {'type': 'Point', 'coordinates': [-121.932962,...            Firetide
# 350  {'type': 'Point', 'coordinates': [-74.008767, ...        Proper Cloth
# 258  {'type': 'Point', 'coordinates': [-73.9878525,...               Pond5
# 234  {'type': 'Point', 'coordinates': [-73.9878525,...               Pond5
# 2    {'type': 'Point', 'coordinates': [-122.055197,...               Plaxo
# 77   {'type': 'Point', 'coordinates': [13.398694, 5...              Plazes
# 382  {'type': 'Point', 'coordinates': [-74.0045549,...          Logicworks
# 252  {'type': 'Point', 'coordinates': [-122.145153,...              vufind
# 247  {'type': 'Point', 'coordinates': [-122.227995,...  LooseHead Software
# 271  {'type': 'Point', 'coordinates': [-122.227995,...  LooseHead Software
# 228  {'type': 'Point', 'coordinates': [-122.145153,...              vufind
# 26   {'type': 'Point', 'coordinates': [-122.321836,...         Respectance
# 118  {'type': 'Point', 'coordinates': [-74.006196, ...          TheLadders
# 7    {'type': 'Point', 'coordinates': [-73.995722, ...              Meetup
# 149  {'type': 'Point', 'coordinates': [-73.9954585,...             Bonobos
# 395  {'type': 'Point', 'coordinates': [-74.00717, 4...       ChallengePost
# 17   {'type': 'Point', 'coordinates': [-122.159928,...            Terabitz
# 182  {'type': 'Point', 'coordinates': [-122.087712,...              Zecter
# 164  {'type': 'Point', 'coordinates': [-122.3370801...         TeachStreet
# 111  {'type': 'Point', 'coordinates': [-121.918319,...             Mixbook
# ..                                                 ...                 ...
# 333  {'type': 'Point', 'coordinates': [-76.998641, ...           Socialize
# 76   {'type': 'Point', 'coordinates': [-122.085807,...              SezWho
# 172  {'type': 'Point', 'coordinates': [9.926475, 53...          zweitgeist
# 330  {'type': 'Point', 'coordinates': [-118.487236,...           Audiolife
# 79   {'type': 'Point', 'coordinates': [-122.296411,...           RepairPal
# 171  {'type': 'Point', 'coordinates': [12.461425, 4...             Memopal
# 327  {'type': 'Point', 'coordinates': [72.856178, 1...              burrp!
# 326  {'type': 'Point', 'coordinates': [-105.124465,...       Copan Systems
# 325  {'type': 'Point', 'coordinates': [103.7807403,...               Zopim
# 324  {'type': 'Point', 'coordinates': [-105.352174,...              Qualvu
# 86   {'type': 'Point', 'coordinates': [-72.930855, ...           Entrecard
# 87   {'type': 'Point', 'coordinates': [-77.095965, ...              WEbook
# 88   {'type': 'Point', 'coordinates': [-80.058401, ...          divorce360
# 89   {'type': 'Point', 'coordinates': [-121.898539,...           CrossLoop
# 302  {'type': 'Point', 'coordinates': [-119.688412,...            LetsCram
# 168  {'type': 'Point', 'coordinates': [-75.377916, ...           BioWizard
# 317  {'type': 'Point', 'coordinates': [-0.468617, 5...              mydeco
# 316  {'type': 'Point', 'coordinates': [-88.144397, ...         CouponCabin
# 315  {'type': 'Point', 'coordinates': [-6.2689465, ...   Green Apple Media
# 314  {'type': 'Point', 'coordinates': [-117.168697,...          StockTwits
# 313  {'type': 'Point', 'coordinates': [-77.038605, ...          RideCharge
# 214  {'type': 'Point', 'coordinates': [-105.219298,...            LifePics
# 311  {'type': 'Point', 'coordinates': [-71.14462, 4...               Drync
# 310  {'type': 'Point', 'coordinates': [-79.3723339,...               Viigo
# 309  {'type': 'Point', 'coordinates': [-111.8714978...           Solavista
# 306  {'type': 'Point', 'coordinates': [-121.9909454...        MarketRiders
# 162  {'type': 'Point', 'coordinates': [103.875336, ...               Whois
# 161  {'type': 'Point', 'coordinates': [-121.98147, ...          ImageShack
# 303  {'type': 'Point', 'coordinates': [-95.9550264,...          mobiManage
# 0    {'type': 'Point', 'coordinates': [-118.393064,...                Geni
#
#      number_of_employees total_money_raised         type  \
# 21                    55             $31.2M  Big company
# 1                  15000              $6.7M  Big company
# 31                   200             $82.7M  Big company
# 125                   60               $61M  Big company
# 184                   65              $4.2M     Start-up
# 99                   175             $51.3M  Big company
# 92                    60             $14.8M     Start-up
# 319                  200             $42.6M  Big company
# 323                  100                $2M  Big company
# 362                    5                $3M     Start-up
# 73                   100             $39.8M  Big company
# 350                    1              $100k     Start-up
# 258                   25              $500k     Start-up
# 234                   25              $500k     Start-up
# 2                     50             $28.3M  Big company
# 77                    15              €3.7M     Start-up
# 382                   75              $7.6M  Big company
# 252                    7              $930k     Start-up
# 247                    6              $500k  Big company
# 271                    6              $500k  Big company
# 228                    7              $930k     Start-up
# 26                    15             $1.75M     Start-up
# 118                  110             $7.25M  Big company
# 7                     75             $18.3M  Big company
# 149                  150             $74.7M     Start-up
# 395                   17              $4.6M     Start-up
# 17                    12               $10M     Start-up
# 182                    8             $2.52M     Start-up
# 164                    8             $3.45M     Start-up
# 111                   90               $11M     Start-up
# ..                   ...                ...          ...
# 333                   10             $1.82M     Start-up
# 76                     9                $1M     Start-up
# 172                   21              €500k     Start-up
# 330                   11              $4.5M     Start-up
# 79                    25             $21.3M     Start-up
# 171                   12                $1M     Start-up
# 327                   40             $2.15M     Start-up
# 326                  144             $68.4M  Big company
# 325                   40              $392k     Start-up
# 324                   80              $2.6M     Start-up
# 86                     1               $70k     Start-up
# 87                    10                $5M     Start-up
# 88                     6              $2.5M     Start-up
# 89                     8             $10.5M     Start-up
# 302                    5              $655k     Start-up
# 168                    8              $1.1M  Big company
# 317                   35             £12.5M     Start-up
# 316                   50               $54M  Big company
# 315                   50              $132M     Start-up
# 314                   12              $8.6M     Start-up
# 313                   75              $8.6M     Start-up
# 214                   12             $1.98M  Big company
# 311                    8             $1.77M     Start-up
# 310                   30             C$7.9M  Big company
# 309                    8              $250k  Big company
# 306                    4              $200k     Start-up
# 162                    6              $600k     Start-up
# 161                   14               $10M  Big company
# 303                   15              $350k     Start-up
# 0                     18             $16.5M     Start-up
#
#                  ratio_Big_Start
# 21                   (3.0, 3, 1)
# 1                    (3.0, 3, 1)
# 31                   (3.0, 3, 1)
# 125                  (3.0, 3, 1)
# 184                  (3.0, 3, 1)
# 99                   (3.0, 3, 1)
# 92                   (3.0, 3, 1)
# 319                  (3.0, 3, 1)
# 323                  (3.0, 3, 1)
# 362                  (3.0, 3, 1)
# 73                   (3.0, 3, 1)
# 350                  (2.5, 5, 2)
# 258                  (2.0, 2, 1)
# 234                  (2.0, 2, 1)
# 2                    (2.0, 2, 1)
# 77                   (2.0, 2, 1)
# 382                  (1.5, 6, 4)
# 252                  (1.5, 3, 2)
# 247                  (1.5, 3, 2)
# 271                  (1.5, 3, 2)
# 228                  (1.5, 3, 2)
# 26    (1.3333333333333333, 4, 3)
# 118                 (1.25, 5, 4)
# 7                    (1.2, 6, 5)
# 149  (1.1111111111111112, 10, 9)
# 395                  (1.0, 8, 8)
# 17                   (1.0, 5, 5)
# 182                  (1.0, 4, 4)
# 164                  (1.0, 4, 4)
# 111                  (1.0, 2, 2)
# ..                           ...
# 333                   (-1, 0, 0)
# 76                    (-1, 0, 0)
# 172                   (-1, 0, 0)
# 330                   (-1, 0, 0)
# 79                    (-1, 0, 0)
# 171                   (-1, 0, 0)
# 327                   (-1, 0, 0)
# 326                   (-1, 0, 0)
# 325                   (-1, 0, 0)
# 324                   (-1, 0, 0)
# 86                    (-1, 0, 0)
# 87                    (-1, 0, 0)
# 88                    (-1, 0, 0)
# 89                    (-1, 0, 0)
# 302                   (-1, 0, 0)
# 168                   (-1, 0, 0)
# 317                   (-1, 0, 0)
# 316                   (-1, 0, 0)
# 315                   (-1, 0, 0)
# 314                   (-1, 0, 0)
# 313                   (-1, 0, 0)
# 214                   (-1, 0, 0)
# 311                   (-1, 0, 0)
# 310                   (-1, 0, 0)
# 309                   (-1, 0, 0)
# 306                   (-1, 0, 0)
# 162                   (-1, 0, 0)
# 161                   (-1, 0, 0)
# 303                   (-1, 0, 0)
# 0                     (-1, 0, 0)
#
# [405 rows x 9 columns]

# %%
ext_rat = lambda x: x[0]
ext_bigs = lambda x: x[1]
ext_starts = lambda x: x[2]
companies['ratioBS'] = companies['ratio_Big_Start'].apply(ext_rat)
companies['Bigs'] = companies['ratio_Big_Start'].apply(ext_bigs)
companies['Startup'] = companies['ratio_Big_Start'].apply(ext_starts)

# %%
# Por lo cual nos conviene tener un ratio positivo, menor a 1.5 y mayor a 0.8
best_options = companies.loc[(companies.ratioBS > 0.8) & (companies.ratioBS < 1.5) & (companies.ratioBS != 0.0)]
best_options = best_options.drop('ratio_Big_Start',axis=1)
# Nuestro último criterio es que haya la mayor cantidad posible de Startups
best_options = best_options.sort_values('Startup',ascending=False)
# Tomamos las 5 mejores locaciones
best_options = best_options.head(5)
best_options
# Out:
#                           _id category_code  founded_year  \
# 378  5d58bb1119ab40d9eb30ee68           web          2009
# 347  5d58bb1119ab40d9eb30ee49           web          2008
# 304  5d58bb1119ab40d9eb30ee1e           web          2008
# 273  5d58bb1119ab40d9eb30edff        mobile          2007
# 149  5d58bb1119ab40d9eb30ed83     ecommerce          2007
#
#                                             loc_office            name  \
# 378  {'type': 'Point', 'coordinates': [-73.986951, ...          Udorse
# 347  {'type': 'Point', 'coordinates': [-73.986951, ...         Wee Web
# 304  {'type': 'Point', 'coordinates': [-73.986951, ...  People Capital
# 273  {'type': 'Point', 'coordinates': [-73.991334, ...           Buzzd
# 149  {'type': 'Point', 'coordinates': [-73.9954585,...         Bonobos
#
#      number_of_employees total_money_raised      type   ratioBS  Bigs  Startup
# 378                    3              $500k  Start-up  0.818182     9       11
# 347                    5              $270k  Start-up  0.818182     9       11
# 304                   10              $2.5M  Start-up  0.818182     9       11
# 273                    9                $4M  Start-up  0.900000     9       10
# 149                  150             $74.7M  Start-up  1.111111    10        9

# %%
m2 = folium.Map(
    location=[39.157898,-101.646620],
    zoom_start=4
)

for loc in list(db.companies2.find({'type':'Big company'})):
    folium.CircleMarker([loc['loc_office']['coordinates'][1],loc['loc_office']['coordinates'][0]],color='red',radius=5,tooltip=(str(loc['loc_office']['coordinates'])+loc['name'])).add_to(m2)

for loc in list(db.companies2.find({'type':'Start-up'})):
    folium.CircleMarker([loc['loc_office']['coordinates'][1],loc['loc_office']['coordinates'][0]],color='blue',radius=5,tooltip=(str(loc['loc_office']['coordinates'])+loc['name'])).add_to(m2)

for comp in range(best_options.shape[0]):
    print(best_options.iloc[comp])
    folium.Marker([best_options.iloc[comp].loc['loc_office']['coordinates'][1],best_options.iloc[comp].loc['loc_office']['coordinates'][0]],tooltip=best_options.iloc[comp].loc['ratioBS']).add_to(m2)  
m2
# Out:
# _id                                             5d58bb1119ab40d9eb30ee68
# category_code                                                        web
# founded_year                                                        2009
# loc_office             {'type': 'Point', 'coordinates': [-73.986951, ...
# name                                                              Udorse
# number_of_employees                                                    3
# total_money_raised                                                 $500k
# type                                                            Start-up
# ratioBS                                                         0.818182
# Bigs                                                                   9
# Startup                                                               11
# Name: 378, dtype: object
# _id                                             5d58bb1119ab40d9eb30ee49
# category_code                                                        web
# founded_year                                                        2008
# loc_office             {'type': 'Point', 'coordinates': [-73.986951, ...
# name                                                             Wee Web
# number_of_employees                                                    5
# total_money_raised                                                 $270k
# type                                                            Start-up
# ratioBS                                                         0.818182
# Bigs                                                                   9
# Startup                                                               11
# Name: 347, dtype: object
# _id                                             5d58bb1119ab40d9eb30ee1e
# category_code                                                        web
# founded_year                                                        2008
# loc_office             {'type': 'Point', 'coordinates': [-73.986951, ...
# name                                                      People Capital
# number_of_employees                                                   10
# total_money_raised                                                 $2.5M
# type                                                            Start-up
# ratioBS                                                         0.818182
# Bigs                                                                   9
# Startup                                                               11
# Name: 304, dtype: object
# _id                                             5d58bb1119ab40d9eb30edff
# category_code                                                     mobile
# founded_year                                                        2007
# loc_office             {'type': 'Point', 'coordinates': [-73.991334, ...
# name                                                               Buzzd
# number_of_employees                                                    9
# total_money_raised                                                   $4M
# type                                                            Start-up
# ratioBS                                                              0.9
# Bigs                                                                   9
# Startup                                                               10
# Name: 273, dtype: object
# _id                                             5d58bb1119ab40d9eb30ed83
# category_code                                                  ecommerce
# founded_year                                                        2007
# loc_office             {'type': 'Point', 'coordinates': [-73.9954585,...
# name                                                             Bonobos
# number_of_employees                                                  150
# total_money_raised                                                $74.7M
# type                                                            Start-up
# ratioBS                                                          1.11111
# Bigs                                                                  10
# Startup                                                                9
# Name: 149, dtype: object
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Finalmente encontramos como muy buena opción la ciudad de New York, según las condiciones de clasificación 
# seleccionadas.
